# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

import yaml
import pandas as pd
from sklearn.model_selection import train_test_split
import optuna

from src.data.prepare_data import prepare_data
from src.models.utils import train_splits, imbalanced_sampling
from src.models.tuner import HyperParamSearch
from src.models.model import Classifier
from src.models.feature_selection import FeatureSelection
from src.models.evaluator import Evaluation

# %%
# read config
with open("../config.yml", "r") as file:
    config=yaml.load(file, Loader= yaml.SafeLoader)
del file

# %%
# load and prepare data
df = pd.read_csv("../"+config["data_loader"]["path"])
df = prepare_data(df=df)
display(df.head())

# check class distributions
df["label"].value_counts(normalize=True)
# Out:
#        time        v1        v2        v3        v4        v5        v6  \
# 0 -1.996580 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996580  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996558 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996558 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996537 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          v7        v8        v9  ...       v21       v22       v23       v24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         v25       v26       v27       v28    amount  label
# 0  0.128539 -0.189115  0.133558 -0.021053  0.244964      0
# 1  0.167170  0.125895 -0.008983  0.014724 -0.342474      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  1.160684      0
# 3  0.647376 -0.221929  0.062723  0.061458  0.140534      0
# 4 -0.206010  0.502292  0.219422  0.215153 -0.073403      0
#
# [5 rows x 31 columns]
# label
# 0    0.998273
# 1    0.001727
# Name: proportion, dtype: float64

# %%
# split dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(columns=["label"]), df["label"]
    , test_size=config["train_test_split"]["test_size"]
    , random_state=config["general"]["seed"]
    , shuffle=True
    , stratify=df["label"]
    )

# %%
# apply oversampling to the train set
X_train_rs, y_train_rs = imbalanced_sampling(
    method="over"
    , X_train=X_train
    , y_train=y_train
)

# check class distributions
print(
    y_train.value_counts(normalize=True)
    , y_train_rs.value_counts(normalize=True)
    )
# Out:
# label
# 0    0.998274
# 1    0.001726
# Name: proportion, dtype: float64 label
# 0    0.5
# 1    0.5
# Name: proportion, dtype: float64

# %%
# split train sets into multiple sets and check class distributions
train = train_splits(X_train_rs, y_train_rs, config["train_test_split"])

# %%
# set tuner for hyperparam optimization
tuner = HyperParamSearch(config=config["optimization"], algorithm="XGBClassifier")

def objective(trial) -> float:
    return tuner.fit(
        X_train=train[1].drop(columns=["label"]),
        y_train=train[1]["label"],
        trial=trial
        )

# set study
study = optuna.create_study(
    direction=config["optimization"]["direction"],
    sampler=optuna.samplers.TPESampler(seed=config["general"]["seed"])
    )
study.optimize(objective, n_trials=config["optimization"]["n_trials"])

print(
    f"Best trial:\n",
    f"- params: {study.best_trial.params}\n",
    f"- score: {study.best_trial.value}", "\n"*2
)
# Out:
# [I 2025-08-30 17:44:27,806] A new study created in memory with name: no-name-38bb6e2e-e1f7-469c-9a40-8186d00b95e3
# [I 2025-08-30 17:44:36,790] Trial 0 finished with value: 0.9996040099814858 and parameters: {'n_estimators': 39, 'max_depth': 20, 'learning_rate': 0.36626497696389115, 'gamma': 5.986584841970366, 'subsample': 0.5780093202212182}. Best is trial 0 with value: 0.9996040099814858.
# [I 2025-08-30 17:44:41,583] Trial 1 finished with value: 0.9968335814414895 and parameters: {'n_estimators': 17, 'max_depth': 4, 'learning_rate': 0.43322189674169265, 'gamma': 6.011150117432088, 'subsample': 0.8540362888980227}. Best is trial 0 with value: 0.9996040099814858.
# [I 2025-08-30 17:44:46,734] Trial 2 finished with value: 0.9988314704366165 and parameters: {'n_estimators': 4, 'max_depth': 20, 'learning_rate': 0.41638887775941047, 'gamma': 2.1233911067827616, 'subsample': 0.5909124836035503}. Best is trial 0 with value: 0.9996040099814858.
# [I 2025-08-30 17:44:53,426] Trial 3 finished with value: 0.9995337268269111 and parameters: {'n_estimators': 20, 'max_depth': 8, 'learning_rate': 0.2628534593844867, 'gamma': 4.319450186421157, 'subsample': 0.645614570099021}. Best is trial 0 with value: 0.9996040099814858.
# [I 2025-08-30 17:45:05,779] Trial 4 finished with value: 0.9993007535735282 and parameters: {'n_estimators': 62, 'max_depth': 5, 'learning_rate': 0.14678017961907386, 'gamma': 3.663618432936917, 'subsample': 0.728034992108518}. Best is trial 0 with value: 0.9996040099814858.
# [I 2025-08-30 17:45:17,120] Trial 5 finished with value: 0.9996854047151087 and parameters: {'n_estimators': 79, 'max_depth': 6, 'learning_rate': 0.2576029847683922, 'gamma': 5.924145688620425, 'subsample': 0.5232252063599989}. Best is trial 5 with value: 0.9996854047151087.
# [I 2025-08-30 17:45:27,658] Trial 6 finished with value: 0.996508906224592 and parameters: {'n_estimators': 62, 'max_depth': 6, 'learning_rate': 0.033460744899654477, 'gamma': 9.488855372533333, 'subsample': 0.9828160165372797}. Best is trial 5 with value: 0.9996854047151087.
# [I 2025-08-30 17:45:42,489] Trial 7 finished with value: 0.9994597550986469 and parameters: {'n_estimators': 82, 'max_depth': 8, 'learning_rate': 0.049738384889185555, 'gamma': 6.842330265121569, 'subsample': 0.7200762468698007}. Best is trial 5 with value: 0.9996854047151087.
# [I 2025-08-30 17:45:47,933] Trial 8 finished with value: 0.9978314956590296 and parameters: {'n_estimators': 14, 'max_depth': 11, 'learning_rate': 0.018159872036493982, 'gamma': 9.093204020787821, 'subsample': 0.6293899908000085}. Best is trial 5 with value: 0.9996854047151087.
# [I 2025-08-30 17:45:57,065] Trial 9 finished with value: 0.999644705842274 and parameters: {'n_estimators': 67, 'max_depth': 8, 'learning_rate': 0.2605139425677276, 'gamma': 5.4671027934327965, 'subsample': 0.5924272277627636}. Best is trial 5 with value: 0.9996854047151087.
# Best trial:
#  - params: {'n_estimators': 79, 'max_depth': 6, 'learning_rate': 0.2576029847683922, 'gamma': 5.924145688620425, 'subsample': 0.5232252063599989}
#  - score: 0.9996854047151087

# %%
# greedy feature selection
clf = Classifier(
    algorithm="XGBClassifier"
    , **study.best_trial.params
    )

feature_selection = FeatureSelection(
    X=train[2].drop(columns=["label"]),
    y=train[2]["label"]
    )
feature_selection.stats_test()
feature_selection.wrapper(clf=clf, config=config["optimization"])

feats = feature_selection.features
feats
# Out:
# Index(['v9', 'v14', 'v18', 'v28'], dtype='object')

# %%
# fit best algorithm on most important features of training data
clf = Classifier(
    algorithm="XGBClassifier"
    , **study.best_trial.params
    )
clf.fit(X=X_train_rs[feats], y=y_train_rs)

# test set evaluation
eval = Evaluation(clf=clf, threshold=0.5)
eval.fit(
    train=(X_train_rs[feats], y_train_rs),
    test=(X_test[feats], y_test)
    )
# Out:
#          accuracy  precision  recall        f1   roc_auc
# dataset
# train    0.999504   0.999009    1.00  0.999504  0.999958
# test     0.998174   0.486486    0.72  0.580645  0.956272
