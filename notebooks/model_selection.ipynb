# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

import yaml
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import optuna

from src.data.prepare_data import prepare_data
from src.models.utils import train_splits, imbalanced_sampling, set_global_seed
from src.models.tuner import HyperParamSearch
from src.models.model import Classifier
from src.models.evaluator import Evaluation
from src.models.tracker import Logging

# %%
# read config
with open("../config.yml", "r") as file:
    config=yaml.load(file, Loader= yaml.SafeLoader)
del file

# ensure reproducibility
set_global_seed(seed=config["general"]["seed"])

# algorithm to be explored
ALGORITHM = "XGBClassifier"

# %%
# load and prepare data
df = pd.read_csv("../" + config["data_loader"]["path"])
df = prepare_data(df=df)
display(df.head())

# check class distributions
df["label"].value_counts(normalize=True)
# Out:
#        time        v1        v2        v3        v4        v5        v6  \
# 0 -1.996580 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996580  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996558 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996558 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996537 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          v7        v8        v9  ...       v21       v22       v23       v24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         v25       v26       v27       v28    amount  label
# 0  0.128539 -0.189115  0.133558 -0.021053  0.244964    0.0
# 1  0.167170  0.125895 -0.008983  0.014724 -0.342474    0.0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  1.160684    0.0
# 3  0.647376 -0.221929  0.062723  0.061458  0.140534    0.0
# 4 -0.206010  0.502292  0.219422  0.215153 -0.073403    0.0
#
# [5 rows x 31 columns]
# label
# 0.0    0.998273
# 1.0    0.001727
# Name: proportion, dtype: float64

# %% [markdown]
# **Train and Test Set**
# - Split whole set into train, validation and test sets using strat sampling
# - Apply oversampling as the number of positive instances is small

# %%
# split dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(columns=["label"]), df["label"]
    , test_size=config["train_test_split"]["test_size"]
    , random_state=config["general"]["seed"]
    , shuffle=True
    , stratify=df["label"]
    )

# split dataset into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train
    , test_size=config["train_test_split"]["test_size"]
    , random_state=config["general"]["seed"]
    , shuffle=True
    , stratify=y_train
    )

# %%
# apply oversampling to the train set
X_train_rs, y_train_rs = imbalanced_sampling(
    method="over"
    , X_train=X_train
    , y_train=y_train
)

# check class distributions
print(
    y_train.value_counts(normalize=True)
    , y_train_rs.value_counts(normalize=True)
    )
# Out:
# label
# 0.0    0.998273
# 1.0    0.001727
# Name: proportion, dtype: float64 label
# 0.0    0.5
# 1.0    0.5
# Name: proportion, dtype: float64

# %% [markdown]
# **Optimization & Evaluation**
# - Hyper-parameters - search which hyper-parameters optimize scoring metric for the given algorithm in the validation set
# - Evaluation - retrieve best hyper-parameters and recover full training set, applying over sampling, to evaluate results on test set

# %%
# set tuner for hyperparam optimization
tuner = HyperParamSearch(config=config['optimization'], algorithm=ALGORITHM)

def objective(trial) -> float:
    return tuner.fit(
        X_train=X_train_rs,
        y_train=y_train_rs,
        trial=trial,
        X_val=X_val,
        y_val=y_val
        )

# set study
study = optuna.create_study(
    direction=config["optimization"]["direction"],
    sampler=optuna.samplers.TPESampler(seed=config["general"]["seed"])
    )
study.optimize(objective, n_trials=config["optimization"]["n_trials"])

# logging
tuner.trials_runs = study.trials_dataframe()
# Out:
# [I 2025-08-31 16:02:48,045] A new study created in memory with name: no-name-2336a87c-e984-4a8c-a2d3-3a11ff14f254
# [I 2025-08-31 16:02:49,585] Trial 0 finished with value: 0.8695652173913043 and parameters: {'n_estimators': 39, 'max_depth': 20, 'learning_rate': 0.36626497696389115, 'gamma': 5.986584841970366, 'subsample': 0.5780093202212182}. Best is trial 0 with value: 0.8695652173913043.
# [I 2025-08-31 16:02:50,598] Trial 1 finished with value: 0.3142857142857143 and parameters: {'n_estimators': 17, 'max_depth': 4, 'learning_rate': 0.43322189674169265, 'gamma': 6.011150117432088, 'subsample': 0.8540362888980227}. Best is trial 0 with value: 0.8695652173913043.
# [I 2025-08-31 16:02:51,516] Trial 2 finished with value: 0.6785714285714286 and parameters: {'n_estimators': 4, 'max_depth': 20, 'learning_rate': 0.41638887775941047, 'gamma': 2.1233911067827616, 'subsample': 0.5909124836035503}. Best is trial 0 with value: 0.8695652173913043.
# [I 2025-08-31 16:02:52,650] Trial 3 finished with value: 0.7843137254901961 and parameters: {'n_estimators': 20, 'max_depth': 8, 'learning_rate': 0.2628534593844867, 'gamma': 4.319450186421157, 'subsample': 0.645614570099021}. Best is trial 0 with value: 0.8695652173913043.
# [I 2025-08-31 16:02:54,457] Trial 4 finished with value: 0.6666666666666666 and parameters: {'n_estimators': 62, 'max_depth': 5, 'learning_rate': 0.14678017961907386, 'gamma': 3.663618432936917, 'subsample': 0.728034992108518}. Best is trial 0 with value: 0.8695652173913043.
# [I 2025-08-31 16:02:56,556] Trial 5 finished with value: 0.875 and parameters: {'n_estimators': 79, 'max_depth': 6, 'learning_rate': 0.2576029847683922, 'gamma': 5.924145688620425, 'subsample': 0.5232252063599989}. Best is trial 5 with value: 0.875.
# [I 2025-08-31 16:02:58,800] Trial 6 finished with value: 0.38095238095238093 and parameters: {'n_estimators': 62, 'max_depth': 6, 'learning_rate': 0.033460744899654477, 'gamma': 9.488855372533333, 'subsample': 0.9828160165372797}. Best is trial 5 with value: 0.875.
# [I 2025-08-31 16:03:01,548] Trial 7 finished with value: 0.8163265306122449 and parameters: {'n_estimators': 82, 'max_depth': 8, 'learning_rate': 0.049738384889185555, 'gamma': 6.842330265121569, 'subsample': 0.7200762468698007}. Best is trial 5 with value: 0.875.
# [I 2025-08-31 16:03:02,690] Trial 8 finished with value: 0.4819277108433735 and parameters: {'n_estimators': 14, 'max_depth': 11, 'learning_rate': 0.018159872036493982, 'gamma': 9.093204020787821, 'subsample': 0.6293899908000085}. Best is trial 5 with value: 0.875.
# [I 2025-08-31 16:03:04,595] Trial 9 finished with value: 0.8333333333333334 and parameters: {'n_estimators': 67, 'max_depth': 8, 'learning_rate': 0.2605139425677276, 'gamma': 5.4671027934327965, 'subsample': 0.5924272277627636}. Best is trial 5 with value: 0.875.

# %%
# fit model on whole training set
X_train, y_train = pd.concat([X_train, X_val]), pd.concat([y_train, y_val])
X_train_rs, y_train_rs = imbalanced_sampling(
    method='over'
    , X_train=X_train
    , y_train=y_train
)

# set algorithm best hyperparams
hyperparams = (
    config["optimization"]["param_grid"][ALGORITHM]["fixed"]
    | study.best_trial.params
)

clf = Classifier(algorithm=ALGORITHM, **hyperparams)
clf.fit(X=X_train_rs, y=y_train_rs)

# test set evaluation
eval = Evaluation(clf=clf, threshold=0.5)
eval.fit(train=(X_train_rs, y_train_rs), test=(X_test, y_test))
# Out:
#          accuracy  precision  recall        f1  roc_auc
# dataset
# train    0.999861   0.999722     1.0  0.999861  0.99999
# test     0.999157   0.740741     0.8  0.769231  0.96637

# %%
# logging experiment
logger = Logging(experiment_name="ModelSelection", run_name=ALGORITHM)
logger.log_tuner(tuner=tuner)
logger.log_run(clf=clf, train=(X_train_rs, y_train_rs), test=(X_test, y_test))
# Out:
# 🏃 View run SEARCH_31AUG2025_1603 at: http://127.0.0.1:5000/#/experiments/361586715199092395/runs/55c8c5f0fc01428e9311f933139831ac
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/361586715199092395
# 🏃 View run XGBClassifier at: http://127.0.0.1:5000/#/experiments/361586715199092395/runs/23480e5ac5924e9c93700dde2cfe8d62
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/361586715199092395
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# 🏃 View run TEST_31AUG2025_1603 at: http://127.0.0.1:5000/#/experiments/361586715199092395/runs/f57ee0a79d4b472aa4133d33a69e981a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/361586715199092395
# 🏃 View run XGBClassifier at: http://127.0.0.1:5000/#/experiments/361586715199092395/runs/23480e5ac5924e9c93700dde2cfe8d62
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/361586715199092395
